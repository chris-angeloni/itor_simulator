# %%
from cellworld import *
import numpy as np
import matplotlib.pyplot as plt
import glob
from tqdm.notebook import tqdm
import pickle
from random import choices
import matplotlib.colors as colors
import matplotlib.cm as cmx

from _src.pose import *
from _src.visibility import *
from _src.itor import *

# %%
# load experiment
e = Experiment.load_from_file('./_data/MICE_20220608_1557_DMM3_21_05_SR5_experiment.json')
vis,w = get_vis(e)

# # load visibility matrix
[A,V,pts,sparse_arr] = pickle.load(open('./_data/visibility-21_05-1000.pkl','rb'))   
vis_graph = {'V':V,'A':A,'src':pts,'dst':sparse_arr}

# %% [markdown]
# ## Build pose library
# The library will have the following columns:
#
# 1. experiment name
# 2. episode
# 3. POSEx
# 4. POXEy
# 5. score

# %%
EXP = []
EPI = []
POSEx = []
POSEy = []
SCORE = []
POSE = []
for j,ep in enumerate(e.episodes):
    pt = ep.trajectories.where('agent_name','prey').get_unique_steps()
    for step in pt:
        posex = []
        posey = []
        score = []
        if step.data:
            pose = PoseList.parse(step.data)
            for i in range(len(pose)):
                posex.append(pose[i].location.x)
                posey.append(pose[i].location.y)
                score.append(pose[i].score)
            EXP.append(e.name)
            EPI.append(j)
            POSEx.append(posex)
            POSEy.append(posey)
            SCORE.append(score)
            POSE.append(pose)
experiment = np.vstack(EXP)
episodes = np.vstack(EPI)
poseX = np.vstack(POSEx)
poseY = np.vstack(POSEy)
score = np.vstack(SCORE)

# %% [markdown]
# ## Compute ITOR
# True value

# %%
# select episode
episode = 14

# for each step in the trajectory, compute true ITOR val
pt = e.episodes[episode].trajectories.where('agent_name','prey').get_unique_steps()
body_parts=['body_mid','tail_base','tail_post_base','tail_pre_tip','tail_tip']
#body_parts=['body_mid']
ITOR = []
ITOR_body = []
for i in tqdm(range(len(pt))):
    step = pt[i]
    if step.data:
        pose = PoseList.parse(step.data)

        # compute true ITOR
        I = compute_itor_pose(pose,
                  step.rotation,
                  vis_graph,
                  head_parts=['head_base'],
                  body_parts=body_parts)
        ITOR.append(I['ITOR'])
        
        # compute ITOR with just the body
        I = compute_itor_pose(pose,
                  step.rotation,
                  vis_graph,
                  head_parts=['head_base'],
                  body_parts=['body_mid'])
        ITOR_body.append(I['ITOR'])
# Out:
#   0%|          | 0/345 [00:00<?, ?it/s]

# %%
_ = plt.hist(ITOR,bins=np.linspace(0,1,30),alpha=0.5,label='full body')
_ = plt.hist(ITOR_body,bins=np.linspace(0,1,30),alpha=0.5,label='COM only')
plt.xlabel('ITOR')
plt.ylabel('count')
plt.legend()

# %% [markdown]
# Null distribution

# %%
k = 500
filename = f'./_data/episode{episode}_{k}null.pkl'
if not glob.glob(filename):
    ITOR_null = []
    poseI = []
    for i in tqdm(range(len(pt))):
        step = pt[i]
        if step.data:
            # get the real pose
            pose0 = PoseList.parse(step.data).copy()
            
            # get null samples
            rand_sample = choices(np.where(episodes != episode)[0],k=k)
            itor = []
            pose_ind = []
            for kk in rand_sample:
                
                # offset and rotate null pose
                pose1 = POSE[kk].copy()
                pose_null,src_angle,src_loc,ref_angle,ref_loc = match_pose(pose0,pose1)

                # compute ITOR and map to color value
                I = compute_itor_pose(pose_null,
                                  ref_angle,
                                  vis_graph,
                                  head_parts=['head_base'],
                                  body_parts=body_parts)
                itor.append(I['ITOR'])
                pose_ind.append(kk)
            ITOR_null.append(itor)
            poseI.append(pose_ind)
        
    pickle.dump([ITOR_null,poseI],open(filename,'wb'))   
else:
    [ITOR_null,poseI] = pickle.load(open(filename,'rb'))

# %%
def pose2array(pose,score=0):
    '''Covert pose to array'''
    return np.vstack([[i.location.x,i.location.y] for i in pose if i.score > score])

def get_null_pose_dist(frame_list,pose_lib,pose0=[]):
    pose_null = []
    for i in enumerate(frame_list):
        if pose0:
            pose_norm,_,_,_,_ = match_pose(
                pose0,
                pose_lib[i])
        else:
            pose_norm = pose_lib[i]
        pose_null.append(pose2array(pose_norm))
    return pose_null

# %%
# pretransform the null pose for plotting
pt = e.episodes[episode].trajectories.where('agent_name','prey').get_unique_steps()
pnull = []
inull = []
for ind in tqdm(range(len(pt)-1)):
    pnull.append(get_null_pose_dist(poseI[ind],POSE,PoseList.parse(pt[ind].data)))
# Out:
#   0%|          | 0/344 [00:00<?, ?it/s]
# [5739, 15048, 1454, 10908, 5886, 4059, 13397, 1684, 10447, 6142, 14497, 10128, 9642, 14157, 16176, 10370, 6528, 13754, 9261, 12675, 3115, 10379, 15299, 11145, 2291, 14270, 4896, 15280, 18600, 8414, 14070, 9752, 3893, 5824, 18243, 8907, 9406, 11084, 1635, 11038, 4896, 17641, 5156, 3591, 10141, 9702, 18306, 5539, 15025, 3124, 3051, 43, 13901, 75, 9777, 10504, 12528, 14834, 18342, 3955, 445, 918, 14527, 12521, 1719, 13742, 9318, 10514, 4718, 17928, 2695, 10810, 12990, 9300, 5174, 15328, 8811, 13434, 13926, 4814, 9008, 1038, 10539, 2149, 11299, 1253, 4396, 14126, 9019, 8758, 14097, 18290, 4507, 5540, 11476, 16830, 9064, 15398, 3425, 14494, 4799, 6890, 17423, 17499, 2119, 11389, 17739, 518, 694, 7617, 3179, 6812, 13636, 7534, 17186, 17570, 12579, 10866, 191, 17454, 3961, 9345, 10981, 18665, 14474, 4065, 107, 1206, 4677, 8287, 3450, 14960, 17759, 14673, 12081, 8611, 567, 12430, 15536, 10072, 12853, 936, 5043, 12924, 4721, 4707, 12312, 7472, 286, 2459, 1026, 17689, 15596, 2935, 4233, 15864, 12511, 8742, 752, 866, 16518, 17009, 18182, 5751, 10571, 9652, 15357, 13835, 13405, 9068, 13041, 8891, 16865, 10820, 12634, 14452, 14548, 914, 9597, 4503, 3393, 8129, 7223, 8227, 4458, 5819, 16535, 3218, 2999, 10417, 12231, 3823, 11949, 16337, 1382, 10782, 17024, 764, 16738, 13816, 12148, 8328, 13592, 12744, 533, 17877, 4372, 14253, 13760, 8633, 15546, 13870, 16688, 17492, 9633, 18665, 7280, 16749, 99, 14899, 3765, 14226, 3821, 7140, 18481, 6518, 14010, 17092, 7584, 9616, 17248, 2078, 7266, 13336, 10292, 11057, 5314, 6442, 15495, 7569, 5911, 18306, 8435, 15660, 17653, 229, 10738, 12352, 7150, 10137, 9356, 14135, 9
914, 1067, 1534, 11920, 7385, 3540, 16919, 7014, 16097, 16291, 14425, 16478, 12367, 13018, 6069, 14271, 2353, 5026, 15582, 12894, 5596, 2973, 3830, 6097, 11252, 18115, 17436, 10911, 9935, 17328, 11664, 11245, 7571, 13928, 434, 4527, 4409, 11134, 17557, 4839, 8785, 15899, 3238, 2129, 12800, 3003, 2810, 1189, 12118, 17527, 14179, 14462, 10402, 2750, 4736, 854, 9066, 3175, 12501, 6549, 13454, 3755, 15297, 6039, 13113, 18596, 7323, 3425, 11651, 9526, 7423, 7431, 13978, 11333, 1356, 15027, 14289, 5047, 8583, 10618, 150, 7303, 14916, 1382, 2537, 8724, 6984, 14457, 3125, 12452, 2557, 10240, 12174, 3733, 9872, 9556, 6922, 9165, 16409, 4561, 13101, 9755, 8756, 10001, 12390, 17604, 15452, 8883, 15314, 2900, 170, 5019, 10444, 2169, 9971, 15485, 2363, 4980, 7325, 18662, 11314, 17791, 6173, 14170, 4948, 16585, 13108, 3157, 14577, 16746, 11122, 310, 5957, 12163, 12414, 12525, 15371, 15130, 1807, 4823, 17134, 9465, 7475, 1860, 8100, 11210, 4130, 17057, 17924, 11898, 11182, 219, 9440, 16813, 14785, 6975, 11731, 6360, 7198, 2428, 15752, 3905, 5749, 13713, 2280, 12022]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [74], in <cell line: 5>()
#       4 inull = []
#       5 for ind in tqdm(range(len(pt)-1)):
# ----> 6     pnull.append(get_null_pose_dist(poseI[ind],POSE,PoseList.parse(pt[ind].data)))
#
# Input In [73], in get_null_pose_dist(frame_list, pose_lib, pose0)
#       8 for i,kk in enumerate(frame_list):
#       9     if pose0:
# ---> 10         pose_norm,_,_,_,_ = match_pose(
#      11             pose0,
#      12             pose_lib[kk])
#      13     else:
#      14         pose_norm = pose_lib[kk]
#
# File ~/chris-lab/projects/prey/_behavior/itor_simulator/_src/pose.py:41, in match_pose(pose0, pose1, ref_part)
#      39 # get reference location and angle
#      40 ref_loc = [i.location for i in pose0 if i.part==ref_part][0]
# ---> 41 ref_angle = get_pose_angle(pose0)
#      43 # get the source location and angle
#      44 src_loc = [i.location for i in pose1 if i.part==ref_part][0]
#
# File ~/chris-lab/projects/prey/_behavior/itor_simulator/_src/pose.py:16, in get_pose_angle(pose, parts)
#      14 def get_pose_angle(pose, parts=['head_base','nose']):
#      15     '''Get angle between two parts of pose object'''
# ---> 16     posec = pose.copy()
#      17     loca = [i.location for i in posec if i.part==parts[0]][0]
#      18     locb = [i.location for i in posec if i.part==parts[1]][0]
#
# File ~/anaconda3/lib/python3.9/site-packages/json_cpp/json_object.py:249, in JsonList.copy(self)
#     248 def copy(self):
# --> 249     return type(self).parse(str(self))
#
# File ~/anaconda3/lib/python3.9/site-packages/json_cpp/json_object.py:265, in JsonList.parse(cls_or_self, json_string, json_list)
#     263 for i in json_list:
#     264     if issubclass(ic, JsonObject):
# --> 265         new_list.append(it.parse(json_dictionary=i))
#     266     elif issubclass(ic, JsonList):
#     267         new_list.append(it.parse(json_list=i))
#
# File ~/anaconda3/lib/python3.9/site-packages/json_cpp/json_object.py:212, in JsonList.append(self, val)
#     211 def append(self, val):
# --> 212     self._typeCheck(val)
#     213     list.append(self, val)
#
# File ~/anaconda3/lib/python3.9/site-packages/json_cpp/json_object.py:178, in JsonList._typeCheck(self, val)
#     176     if self.list_type is float and type(val) is int: #json ints can also be floats
#     177         val = float(val)
# --> 178     check_type(val, self.list_type, "Wrong type %s, this list can hold only instances of %s" % (type(val), str(self.list_type)))
#     179 else:
#     180     if not (issubclass(type(val), JsonObject) or isinstance(val, (str, int, float, bool, JsonList))):
#
# KeyboardInterrupt:

# %%
get_null_pose_dist(poseI[ind],POSE,PoseList.parse(pt[ind].data))
# Out:
# [18130, 2211, 704, 13530, 16134, 13388, 11600, 1394, 4223, 17536, 9671, 16801, 15814, 1399, 3199, 8240, 17204, 13161, 17982, 3156, 8855, 14950, 5250, 12313, 14730, 18011, 16300, 8400, 2649, 3991, 2980, 5062, 15222, 11752, 1674, 4499, 18325, 1016, 2287, 14852, 829, 16356, 4635, 9653, 17282, 12891, 12129, 11781, 10785, 11341, 17227, 14569, 14470, 7617, 5187, 17404, 14833, 6594, 8062, 15255, 8177, 9687, 1644, 9123, 15615, 8114, 14489, 16151, 18260, 15742, 1735, 334, 14347, 8551, 16859, 2944, 5028, 946, 16247, 16574, 892, 10400, 17225, 8661, 1288, 8793, 8613, 9318, 13966, 8757, 9032, 16264, 7031, 51, 940, 18609, 17071, 14297, 18202, 5948, 5451, 10834, 16276, 17382, 3173, 8490, 15066, 1051, 2942, 2511, 7096, 15969, 14619, 16641, 17071, 9901, 1606, 4904, 15407, 10967, 13080, 16317, 15851, 8089, 4487, 14861, 14380, 15289, 14721, 13036, 17118, 11759, 200, 7560, 5849, 8702, 1166, 10355, 66, 12100, 644, 10457, 11154, 18354, 11931, 17479, 15590, 13600, 14976, 5230, 16516, 2481, 5100, 888, 3754, 9064, 1441, 14749, 17754, 5663, 9969, 17012, 16147, 16159, 3078, 3854, 827, 4637, 1622, 8053, 2982, 14542, 11619, 8515, 3775, 3329, 1480, 11581, 2643, 2419, 12027, 14718, 11587, 11646, 388, 16439, 8604, 357, 11594, 18011, 4799, 14846, 8256, 10548, 6185, 5253, 7342, 9605, 16897, 462, 12320, 1104, 17823, 3225, 11705, 14117, 12758, 8835, 557, 13891, 15066, 1496, 2498, 14659, 12326, 6633, 9107, 1716, 14741, 16877, 11153, 14912, 12925, 14528, 7358, 4228, 17239, 3788, 4037, 7076, 13445, 6168, 10090, 14555, 8530, 10818, 13384, 181, 14592, 15239, 12981, 14475, 9927, 4432, 16144, 10613, 17765, 12591, 8144, 6303, 12671, 10566, 14539, 15575, 5003, 8256, 9516, 18174, 14256, 15531, 11901, 9754, 14713, 17046, 7471, 14451, 10914, 6375, 14515, 3875, 18456, 4895, 8292, 14003, 18042, 9669, 4057, 9028, 5526, 8788, 1371, 14948, 14904, 4308, 12636, 6438, 754, 4390, 2996, 9375, 4238, 5754, 17990, 375, 18427, 9591, 10490, 10307, 15153, 1504, 11618, 13731, 6074, 13494, 6283, 18585, 14457, 18361, 9618, 6420, 3180, 3955, 11364, 3336, 4647, 9984, 10360, 17303, 15200, 301, 17906, 13832, 6024, 5383, 5924, 4694, 7448, 18405, 4165, 3282, 3919, 16565, 12181, 4062, 8482, 17154, 16215, 9662, 9246, 7648, 6248, 4183, 4688, 7142, 12657, 14142, 6218, 7321, 9815, 12728, 12498, 9075, 587, 2110, 458, 10547, 3363, 5651, 17801, 7337, 9068, 621, 16182, 15476, 2371, 9265, 6565, 6647, 8104, 488, 8600, 1118, 11370, 6475, 9780, 13865, 8935, 2240, 2590, 12692, 6695, 17295, 15174, 11738, 11653, 6622, 5318, 11857, 7471, 2467, 1056, 6491, 2770, 11168, 16769, 3363, 18292, 16247, 1764, 10686, 11741, 17125, 3971, 12375, 2788, 3963, 3575, 7287, 11678, 8238, 18209, 16819, 13226, 14750, 13542, 13577, 4848, 12722, 12691, 5354, 15572, 18101, 11935, 452, 6926, 2142, 15407, 9115, 4854, 805, 13302, 15842, 16286, 10639, 16998, 7027, 8712, 11050, 6976, 14365, 10324, 18624, 9122, 13890, 17673, 10439, 3529, 2556, 1941, 14631, 15382, 106, 7207, 18608, 2309, 18217, 5081, 9232, 13730, 11199, 15930, 10168, 2909, 10045, 282, 16429, 6282, 18031, 15805, 12164, 6024, 6851, 17199, 13518, 15388, 10276, 14239, 15280, 13800, 216, 15240, 14805, 16939, 3644, 1371, 12771, 2947, 2959, 11024, 3801, 8405, 5721, 16330, 9891, 6684, 8066, 10737, 16606, 2278, 11655]

# %%
# set episode, samples etc
k = 500
episode = 14
pt = e.episodes[episode].trajectories.where('agent_name','prey').get_unique_steps()
rt = e.episodes[episode].trajectories.where('agent_name','predator')
duration = len(pt) / 30 # convert to time

def make_frame(ind):
    
    print(f'frame {ind} / {len(pt)}')
    fig,ax = plt.subplots(2,2,figsize=(10,10))
    
    # copy original pose
    step = pt[ind]
    pose0 = PoseList.parse(step.data).copy()
    
    # plot each display
    d0 = Display(w, fig_size=(7,9), padding=0, cell_edge_color="lightgrey",fig=fig,ax=ax[0,0])
    d1 = Display(w, fig_size=(7,9), padding=0, cell_edge_color="lightgrey",fig=fig,ax=ax[0,1])
    
    # set the colormap
    cm = plt.get_cmap('jet')
    cNorm = colors.Normalize(vmin=0,vmax=1)
    scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=cm)
    
    # sample and plot random poses
    itor = []
    h = []
    for i,kk in enumerate(poseI[ind]):

        # get a pose draw
        pose1 = POSE[kk].copy()

        # offset and rotate each point
        pose_norm,src_angle,src_loc,ref_angle,ref_loc = match_pose(pose0,pose1)

        # cmap and plot
        itor.append(ITOR_null[ind][i])
        cval = scalarMap.to_rgba(ITOR_null[ind][i])
        h = plot_pose(pose_norm,ax=ax[0,0],color=cval,alpha=0.1)
        h = plot_pose(pose_norm,ax=ax[0,1],color=cval,alpha=0.1)
        
    h = plot_pose(pose0,ax=ax[0,0],color='w')
    ax[0,0].axis('scaled')
    ax[0,0].set_xlabel('x')
    ax[0,0].set_ylabel('y')
    ax[0,0].set_xlim([-0.1,1.1])
    ax[0,0].set_ylim([-0.1,1.1])
    plt.setp(h[0],edgecolor='k',sizes=[15])
    plt.setp(h[1],markeredgecolor='k',ms=5)
    plt.setp(h[2],markeredgecolor='k',ms=3)
    
    # get robot for this frame and plot
    rind = np.where(np.array(rt.get('frame'))==step.frame)[0]
    if len(rind) > 0:
        # update location
        rloc = rt[rind[0]].location
        ax[0,0].plot(rloc.x,rloc.y,'rD',markersize=10)
        ax[0,1].plot(rloc.x,rloc.y,'rD',markersize=10)

    h = plot_pose(pose0,ax=ax[0,1],color='w')
    ax[0,1].axis('scaled')
    ax[0,1].set_xlim([ref_loc.x-0.1,ref_loc.x+0.1])
    ax[0,1].set_ylim([ref_loc.y-0.1,ref_loc.y+0.1])
    ax[0,1].set_xlabel('x')
    ax[0,1].set_ylabel('y')
    plt.setp(h[0],edgecolor='k',sizes=[50])
    plt.setp(h[1],markeredgecolor='k',ms=15)
    plt.setp(h[2],markeredgecolor='k',ms=12)
    plt.colorbar(scalarMap,ax=ax[0,1])

    ax[1,0].plot(ITOR,label='ITOR(t)')
    ax[1,0].axvline(ind,color='r',label='true pose')
    ax[1,0].set_xlabel('frame')
    ax[1,0].set_ylabel('ITOR')
    ax[1,0].set_ylim((0,1))
    ax[1,0].legend()
    ax[1,0].set_title(f'frame {ind}')

    ax[1,1].hist(itor,bins=np.linspace(0,1,30),label='random pose')
    ax[1,1].axvline(ITOR[ind],color='r',label='frame')
    ax[1,1].set_ylabel('count')
    ax[1,1].set_xlabel('ITOR')
    ax[1,1].set_xlim([0,1])
    ax[1,1].set_ylim([0,500])
    ax[1,1].legend()
    ax[1,1].set_title(f'percentile = {np.sum(np.array(itor)<=ITOR[ind])/np.sum(~np.isnan(np.array(itor)))}')

    fig.savefig(f'./_plots/episode{episode}/frame_{ind:03d}.jpeg')
    plt.close()
    
start = 0
for i in tqdm(range(start,len(pt)-1)):
    make_frame(i)
# Out:
#   0%|          | 0/345 [00:00<?, ?it/s]
# frame 0 / 345
# frame 1 / 345
# frame 2 / 345
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 93>()
#      92 start = 0
#      93 for i in tqdm(range(start,len(pt))):
# ---> 94     make_frame(i)
#
# Input In [13], in make_frame(ind)
#      39     cval = scalarMap.to_rgba(ITOR_null[ind][i])
#      40     h = plot_pose(pose_norm,ax=ax[0,0],color=cval,alpha=0.1)
# ---> 41     h = plot_pose(pose_norm,ax=ax[0,1],color=cval,alpha=0.1)
#      43 h = plot_pose(pose0,ax=ax[0,0],color='w')
#      44 ax[0,0].axis('scaled')
#
# File ~/chris-lab/projects/prey/_behavior/itor_simulator/_src/pose.py:77, in plot_pose(pose, ax, **plt_kwargs)
#      75 npoint = np.hstack(npoint)
#      76 h = []
# ---> 77 h.append(ax.scatter(ppoints[:,0],ppoints[:,1],**plt_kwargs))
#      78 h.append(ax.plot(hpoint[0],hpoint[1],'*',color=h[0].get_facecolors()[0]))
#      79 h.append(ax.plot(npoint[0],npoint[1],'^',color=h[0].get_facecolors()[0]))
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:4487, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4484     if self._ymargin < 0.05 and x.size > 0:
#    4485         self.set_ymargin(0.05)
# -> 4487 self.add_collection(collection)
#    4488 self._request_autoscale_view()
#    4490 return collection
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:2243, in _AxesBase.add_collection(self, collection, autolim)
#    2239 if autolim:
#    2240     # Make sure viewLim is not stale (mostly to match
#    2241     # pre-lazy-autoscale behavior, which is not really better).
#    2242     self._unstale_viewLim()
# -> 2243     datalim = collection.get_datalim(self.transData)
#    2244     points = datalim.get_points()
#    2245     if not np.isinf(datalim.minpos).all():
#    2246         # By definition, if minpos (minimum positive value) is set
#    2247         # (i.e., non-inf), then min(points) <= minpos <= max(points),
#    2248         # and minpos would be superfluous. However, we add minpos to
#    2249         # the call so that self.dataLim will update its own minpos.
#    2250         # This ensures that log scales see the correct minimum.
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/collections.py:288, in Collection.get_datalim(self, transData)
#     282     # Don't convert transform to transform.get_affine() here because
#     283     # we may have transform.contains_branch(transData) but not
#     284     # transforms.get_affine().contains_branch(transData).  But later,
#     285     # be careful to only apply the affine part that remains.
#     287 if isinstance(offsets, np.ma.MaskedArray):
# --> 288     offsets = offsets.filled(np.nan)
#     289     # get_path_collection_extents handles nan but not masked arrays
#     291 if len(paths) and len(offsets):
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/ma/core.py:3791, in MaskedArray.filled(self, fill_value)
#    3789     result = self._data.copy('K')
#    3790     _recursive_filled(result, self._mask, fill_value)
# -> 3791 elif not m.any():
#    3792     return self._data
#    3793 else:
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:57, in _any(a, axis, dtype, out, keepdims, where)
#      54 def _any(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      55     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      56     if where is True:
# ---> 57         return umr_any(a, axis, dtype, out, keepdims)
#      58     return umr_any(a, axis, dtype, out, keepdims, where=where)
#
# KeyboardInterrupt:

# %%
fig,ax = plt.subplots(2,2,figsize=(10,10))

def plot_itor_null(pt,frame,w,ax=[],fig=[]):
      
    if not ax or not fig:
        fig,ax = plt.subplots(1,1)
        
    # plot the display
    d = Display(w, fig_size=(7,9), padding=0, cell_edge_color="lightgrey",fig=fig,ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 pose_norm
#
# NameError: name 'pose_norm' is not defined

# %%
for ind in range(len(pt)):

    # copy original pose
    step = pt[ind]
    if step.data:
        pose0 = PoseList.parse(step.data).copy()
        pose1 = POSE[poseI[ind][0]].copy()
        pose_norm,src_angle,src_loc,ref_angle,ref_loc = match_pose(pose0,pose1)
        break

# %%
def pose2array(pose,score=0.8):
    return np.vstack([[i.location.x,i.location.y] for i in pose if i.score > score])

# %%
pa = pose2array(pose_norm,score=0.8)
h.append(plt.scatter(pa[:,0],pa[:,1],10))

# %%
pose_norm
# Out:
# [{"part":"body_mid","location":{"x":0.013254697835741923,"y":0.48973852321527217},"camera":0,"score":1.0},{"part":"head_base","location":{"x":0.017063500000000002,"y":0.4995721249999999},"camera":0,"score":1.0},{"part":"nose","location":{"x":0.017063500000000002,"y":0.5082784516929704},"camera":0,"score":1.0},{"part":"tail_base","location":{"x":0.010651641631349884,"y":0.47550416971865567},"camera":0,"score":1.0},{"part":"tail_post_base","location":{"x":0.012203368654815173,"y":0.46455747636546},"camera":0,"score":1.0},{"part":"tail_pre_tip","location":{"x":0.013028235517706717,"y":0.45354353636769823},"camera":0,"score":0.9999879002571106},{"part":"tail_tip","location":{"x":0.010228840720083386,"y":0.44061269038999057},"camera":0,"score":0.9819314181804657}]
